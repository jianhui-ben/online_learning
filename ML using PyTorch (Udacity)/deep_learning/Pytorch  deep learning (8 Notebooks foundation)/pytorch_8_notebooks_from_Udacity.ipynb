# %%
# !git clone https://github.com/udacity/DSND_Term1.git
# Out:
# Cloning into 'DSND_Term1'...
# remote: Enumerating objects: 334, done.
# remote: Total 334 (delta 0), reused 0 (delta 0), pack-reused 334
# Receiving objects: 100% (334/334), 21.92 MiB | 8.66 MiB/s, done.
# Resolving deltas: 100% (80/80), done.

# %%
pwd
# Out:
# '/content'

# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)
drive.mount(ROOT)           # we mount the google drive at /content/drive
# Out:
# /content/drive
# Mounted at /content/drive

# %%
# !cp -v /content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/* /content/drive/My\ Drive/Colab\ Notebooks
# Out:
# cp: -r not specified; omitting directory '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/assets'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/fc_model.py' -> '/content/drive/My Drive/Colab Notebooks/fc_model.py'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/helper.py' -> '/content/drive/My Drive/Colab Notebooks/helper.py'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 1 - Tensors in PyTorch (Exercises).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 1 - Tensors in PyTorch (Exercises).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 1 - Tensors in PyTorch (Solution).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 1 - Tensors in PyTorch (Solution).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 2 - Neural Networks in PyTorch (Exercises).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 2 - Neural Networks in PyTorch (Exercises).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 2 - Neural Networks in PyTorch (Solution).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 2 - Neural Networks in PyTorch (Solution).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 3 - Training Neural Networks (Exercises).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 3 - Training Neural Networks (Exercises).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 3 - Training Neural Networks (Solution).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 3 - Training Neural Networks (Solution).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 4 - Fashion-MNIST (Exercises).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 4 - Fashion-MNIST (Exercises).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 4 - Fashion-MNIST (Solution).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 4 - Fashion-MNIST (Solution).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 5 - Inference and Validation (Exercises).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 5 - Inference and Validation (Exercises).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 5 - Inference and Validation (Solution).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 5 - Inference and Validation (Solution).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 6 - Saving and Loading Models.ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 6 - Saving and Loading Models.ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 7 - Loading Image Data (Exercises).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 7 - Loading Image Data (Exercises).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 7 - Loading Image Data (Solution).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 7 - Loading Image Data (Solution).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 8 - Transfer Learning (Exercises).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 8 - Transfer Learning (Exercises).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/Part 8 - Transfer Learning (Solution).ipynb' -> '/content/drive/My Drive/Colab Notebooks/Part 8 - Transfer Learning (Solution).ipynb'
# '/content/DSND_Term1/lessons/DeepLearning/new-intro-to-pytorch/README.md' -> '/content/drive/My Drive/Colab Notebooks/README.md'
